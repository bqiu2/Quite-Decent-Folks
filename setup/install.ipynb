# %%
#install package
# %pip install -r requirements.txt
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------------------ --------------- 1.6/2.6 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 6.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    --------------- ------------------------ 1.6/4.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.1 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 6.6 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [ftfy]
#    ---------------------------------------- 0/4 [ftfy]
# ...

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 2.5.0
# annotated-doc           0.0.5
# anyio                   4.14.2
# asttokens               3.0.2
# certifi                 2026.7.22
# cffi                    2.1.1
# click                   8.4.2
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.21
# executing               2.2.1
# filelock                3.32.2
# flatbuffers             25.12.19
# fonttools               4.63.0
# fsspec                  2026.7.0
# h11                     0.16.0
# hf-xet                  1.6.0
# httpcore                1.0.9
# httpx                   0.28.1
# huggingface_hub         1.27.0
# idna                    3.18
# ipykernel               7.3.0
# ipython                 9.16.1
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# Jinja2                  3.1.6
# ...
